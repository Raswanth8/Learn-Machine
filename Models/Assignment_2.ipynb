# %% [markdown]
# ## Assignment 2
#
# #### Name : Raswanth S.R
# #### RollNum : CB.EN.U4CSE19648

# %% [markdown]
# ### Mathplotib

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
plt.plot("sex","age",data =df)

# %%
plt.plot("survived","fare",data =df)

# %%
df = df.head(10)

# %%
plt.plot("survived","fare",data =df)

# %%
plt.plot("survived","fare",'o',data =df)

# %%
plt.plot("survived",marker ='o',data =df)

# %%
plt.plot("survived",'o-.b',data =df)

# %%
plt.plot("survived",marker ='o',ms =20,mec='r',mfc='pink',data =df)

# %%
plt.plot("survived",linestyle ='--',color='green',data =df)

# %%
plt.plot("survived","fare",data =df)
plt.plot("sex","fare",data =df)
plt.show()

# %%
df = df.head(25)
font1 = {'family':'serif','color':'green','size': 15}
font2 = {'family':'serif','color':'blue','size': 15}
font3 = {'family':'serif','color':'blue','size': 25}
plt.title("TITANIC",fontdict = font3)
plt.xlabel("Survival rate",fontdict = font1)
plt.ylabel("Gender rate",fontdict = font2)
plt.grid(color='green',linestyle='--',linewidth=1.5)
plt.plot("survived","sex",data =df)
plt.show()

# %%
x = np.array([1,2,3,4])
y = np.array([40,30,90,50])

plt.subplot(3,2,2)
plt.plot(x,y)
font1 = {'family':'serif','color':'green','size': 15}
font2 = {'family':'serif','color':'blue','size': 15}
font3 = {'family':'serif','color':'blue','size': 18}
plt.title("Subplot",fontdict = font3)
plt.suptitle("Subplot 1",fontdict = font2)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter("survived","adult_male",data =df,alpha = 0.3)
plt.scatter("age","adult_male",data =df,alpha =0.5)

plt.show()

# %%
x = np.random.randint(300,size=(100))
y = np.random.randint(300,size=(100))

colors = np.random.randint(100,size=(100))
size = 10*np.random.randint(100,size=(100))
plt.scatter(x,y,c=colors,s=size,alpha=0.5,cmap='nipy_spectral')
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.barh("sex","age",data =df,color='green',height =0.3)
plt.show()

# %%
plt.bar("sex","age",data =df,color='green',width =0.3)
plt.show()

# %%
plt.hist("age",data =df,color='green')
plt.show()

# %%
df = df.head(4)
lab = ['one','two','three','four']
plt.pie("age",data =df,labels =lab,startangle=90)
plt.legend(loc = 'lower left',bbox_to_anchor=(1,0.2))
plt.show()

# %% [markdown]
# ### Seaborn

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.lineplot(x='fare',y='age',data=df)
plt.title('Titanic Dataset')
plt.xlim(5)
plt.show()

# %%
sns.lineplot(x='fare',y='age',data=df)
plt.title('Titanic Dataset')
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
plt.show()

# %%
sns.lineplot(x='fare',y='age',data=df)
plt.title('Titanic Dataset')
sns.despine()
plt.show()

# %%
sns.lineplot(x='fare',y='age',data=df)
plt.title('Titanic Dataset')
plt.figure(figsize=(4,4))
sns.despine()
plt.show()

# %%
sns.lineplot(x='fare',y='age',data=df)
sns.set_context('talk')
plt.show()

# %%
palette = sns.color_palette()

# %%
sns.palplot(palette)

# %%
palette = sns.color_palette('Greens',11)
sns.palplot(palette)

# %%
sns.barplot(x='sex',y='age',data =df)
plt.show()

# %%
sns.countplot(x='sex',data =df)
plt.show()

# %%
sns.boxplot(x='sex',y='age',data =df)
plt.show()

# %%
sns.violinplot(x='sex',y='age',data =df)
plt.show()

# %%
sns.stripplot(x='sex',y='age',data =df)
plt.show()

# %%
sns.histplot(x='age',data =df)
plt.show()

# %%
sns.displot(df['age'])
plt.show()

# %%
sns.pairplot(data=df)
plt.show()
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.regplot(x='fare',y='survived',data =df)
plt.show()

# %%
tc = df.corr()
sns.heatmap(tc)
plt.show()

# %% [markdown]
# ### Data Visualization

# %%
df = df.groupby('who')['fare'].sum().to_frame().reset_index()

# %%
font1 = {'family':'serif','color':'green','size': 15}
font2 = {'family':'serif','color':'blue','size': 15}
font3 = {'family':'serif','color':'blue','size': 18}
plt.title("Bar Horizontal",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.barh(df['who'],df['fare'],color=['blue','green','red'])
plt.show()

# %%
sns.barplot(x='fare',y='who',data=df,palette='Blues')
plt.title("Bar Horizontal",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
font1 = {'family':'serif','color':'green','size': 15}
font2 = {'family':'serif','color':'blue','size': 15}
font3 = {'family':'serif','color':'blue','size': 18}
plt.title("Bar ",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.bar(df['who'],df['fare'],color=['blue','green','red'])
plt.show()

# %%
sns.barplot(x='who',y='fare',data=df,palette='Blues')
plt.title("Bar ",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
df = sns.load_dataset("titanic")
df_pivot = pd.pivot_table(df,values ='fare',index='who',columns='class',aggfunc=np.mean)
ax= df_pivot.plot(kind='bar',alpha =0.8)
plt.title("Grouped Bar ",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
# Out:
# Text(0, 0.5, 'y')

# %%
sns.barplot(x='who',y='fare',hue='class',data=df,palette='Blues')
plt.title("Grouped Bar ",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = df.head(100)
df.plot(x='sex',y='age',stacked = True,title='Stacked Bar')
plt.title("Stacked Bar ",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
df = df.groupby('who')['fare'].sum().to_frame().reset_index()
plt.plot(df['who'],df['fare'])
plt.title("Line ",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
sns.lineplot(x='who',y='fare',data =df)
plt.title("Line  ",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
df = sns.load_dataset("titanic")
df = df.head(4)
lab = ['one','two','three','four']
plt.title("Pie ",fontdict = font3)
plt.pie("age",data =df,labels =lab,startangle=90)
plt.legend(loc = 'lower left',bbox_to_anchor=(1,0.2))
plt.show()

# %%
df = sns.load_dataset("titanic")
df = df.head(4)
lab = ['one','two','three','four']
plt.stackplot('age','fare',data = df,labels = lab)
plt.legend(loc = 'lower left',bbox_to_anchor=(1,0.2))
plt.title("Stacked",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
df = sns.load_dataset("titanic")
sns.displot(df['sex'],kde=False)
plt.title("Column Histogram",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
df = sns.load_dataset("titanic")
sns.displot(df['sex'],kde=True)
plt.title("Line Histogram",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
df = sns.load_dataset("titanic")
df = df.groupby('who')['fare'].sum().to_frame().reset_index()
sns.scatterplot(x="who",data =df,y='fare')
plt.title("Scatter",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
df = df.groupby('who')['fare'].sum().to_frame().reset_index()
plt.scatter(df['who'],df['fare'])
plt.title("Scatter ",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
df = sns.load_dataset("titanic")
df = df.groupby('who')['fare'].sum().to_frame().reset_index()
sns.scatterplot(x="who",data =df,y='fare',hue='who',size='who')
plt.title("Bubble",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()

# %%
df = sns.load_dataset("titanic")
df = df.head(100)
sns.boxplot(x='sex',y='age',data =df)
plt.title("Box",fontdict = font3)
plt.xlabel("x",fontdict = font1)
plt.ylabel("y",fontdict = font2)
plt.show()
